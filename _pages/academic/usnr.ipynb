# %%
library(dplyr)
library(stringr)
df = read.csv('usnr.csv')
df %>% head
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#   X
# 1 0
# 2 1
# 3 2
# 4 3
# 5 4
# 6 5
#   University
# 1 University of Texas--San Antonio (Department of Management Science and Statistics)
# 2 University of North Carolina--Charlotte (Department of Mathematics and Statistics)
# 3 Virginia Commonwealth University (Department of Biostatistics)
# 4 University of Cincinnati (Division of Epidemiology & Biostatistics)
# 5 University at Albany--SUNY (Department of Epidemiology & Biostatistics)
# 6 San Diego State University (Department of Mathematics and Statistics)
#   Location        Rank
# 1 San Antonio, TX 97
# 2 Charlotte, NC   97
# 3 Richmond, VA    93
# 4 Cincinnati, OH  93
# 5 Rensselaer, NY  93
# 6 San Diego, CA   93

# %%
library(stargazer)
df2 <- df %>% filter(str_detect(University, 'Bio.|Public|Health')) %>% 
arrange(Rank) %>% 
mutate(Rank2 = rank(Rank, ties.method = 'min')) %>%
select(-X)
stargazer(df2, out = 'usnr_stat.html', type = 'html', summary = F)
# Out:
# Please cite as:
#
#
#  Hlavac, Marek (2018). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.2. https://CRAN.R-project.org/package=stargazer
#
#
#
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td>University</td><td>Location</td><td>Rank</td><td>Rank2</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">1</td><td>University of Washington (Department of Biostatistics)</td><td>Seattle, WA</td><td>3</td><td>1</td></tr>
# <tr><td style="text-align:left">2</td><td>Johns Hopkins University (Department of Biostatistics)</td><td>Baltimore, MD</td><td>3</td><td>1</td></tr>
# <tr><td style="text-align:left">3</td><td>Harvard University (Department of Biostatistics)</td><td>Boston, MA</td><td>3</td><td>1</td></tr>
# <tr><td style="text-align:left">4</td><td>University of North Carolina--Chapel Hill (Department of Biostatistics)</td><td>Chapel Hill, NC</td><td>8</td><td>4</td></tr>
# <tr><td style="text-align:left">5</td><td>University of Michigan--Ann Arbor (Department of Biostatistics)</td><td>Ann Arbor, MI</td><td>11</td><td>5</td></tr>
# <tr><td style="text-align:left">6</td><td>University of California--Berkeley (Group in Biostatistics)</td><td>Berkeley, CA</td><td>12</td><td>6</td></tr>
# <tr><td style="text-align:left">7</td><td>University of Wisconsin--Madison (School of Medicine and Public Health)</td><td>Madison, WI</td><td>24</td><td>7</td></tr>
# <tr><td style="text-align:left">8</td><td>University of Minnesota--Twin Cities (School of Public Health)</td><td>Minneapolis, MN</td><td>24</td><td>7</td></tr>
# <tr><td style="text-align:left">9</td><td>University of Texas MD Anderson (Department of Biostatistics)</td><td>Houston, TX</td><td>27</td><td>9</td></tr>
# <tr><td style="text-align:left">10</td><td>University of California--Los Angeles (Department of Biostatistics)</td><td>Los Angeles, CA</td><td>27</td><td>9</td></tr>
# <tr><td style="text-align:left">11</td><td>Columbia University (Department of Biostatistics)</td><td>New York, NY</td><td>27</td><td>9</td></tr>
# <tr><td style="text-align:left">12</td><td>Yale University (Department of Biostatistics)</td><td>New Haven, CT</td><td>31</td><td>12</td></tr>
# <tr><td style="text-align:left">13</td><td>University of Pennsylvania (Department of Biostatistics</td><td>Epidemiology)</td><td>Philadelphia, PA</td><td>31</td></tr>
# <tr><td style="text-align:left">14</td><td>Emory University (Department of Biostatistics and Bioinformatics)</td><td>Atlanta, GA</td><td>37</td><td>14</td></tr>
# <tr><td style="text-align:left">15</td><td>Rutgers University--New Brunswick (Department of Statistics and Biostatistics)</td><td>Piscataway, NJ</td><td>40</td><td>15</td></tr>
# <tr><td style="text-align:left">16</td><td>Vanderbilt University (Department of Biostatistics)</td><td>Nashville, TN</td><td>44</td><td>16</td></tr>
# <tr><td style="text-align:left">17</td><td>Duke University (Department of Biostatistics and Bioinformatics)</td><td>Durham, NC</td><td>44</td><td>16</td></tr>
# <tr><td style="text-align:left">18</td><td>Brown University (Department of Biostatistics)</td><td>Providence, RI</td><td>44</td><td>16</td></tr>
# <tr><td style="text-align:left">19</td><td>University of Pittsburgh (Department of Biostatistics)</td><td>Pittsburgh, PA</td><td>50</td><td>19</td></tr>
# <tr><td style="text-align:left">20</td><td>University of California--Davis (Graduate Group in Biostatistics)</td><td>Davis, CA</td><td>50</td><td>19</td></tr>
# <tr><td style="text-align:left">21</td><td>Boston University (School of Public Health)</td><td>Boston, MA</td><td>50</td><td>19</td></tr>
# <tr><td style="text-align:left">22</td><td>University of Texas Health Science Center--Houston (University of Texas MD Anderson Cancer Center UTHealth)</td><td>Houston, TX</td><td>55</td><td>22</td></tr>
# <tr><td style="text-align:left">23</td><td>University of Rochester (Department of Biostatistics and Computational Biology)</td><td>Rochester, NY</td><td>55</td><td>22</td></tr>
# <tr><td style="text-align:left">24</td><td>University of Iowa (Department of Biostatistics)</td><td>Iowa City, IA</td><td>55</td><td>22</td></tr>
# <tr><td style="text-align:left">25</td><td>University of Florida (Department of Biostatistics)</td><td>Gainesville, FL</td><td>55</td><td>22</td></tr>
# <tr><td style="text-align:left">26</td><td>Medical College of Wisconsin (Division of Biostatistics)</td><td>Milwaukee, WI</td><td>61</td><td>26</td></tr>
# <tr><td style="text-align:left">27</td><td>University of Illinois--Chicago (Epidemiology and Biostatistics Division)</td><td>Chicago, IL</td><td>67</td><td>27</td></tr>
# <tr><td style="text-align:left">28</td><td>Case Western Reserve University (Department of Epidemiology and Biostatistics)</td><td>Cleveland, OH</td><td>69</td><td>28</td></tr>
# <tr><td style="text-align:left">29</td><td>University of Colorado--Denver (Department of Biostatistics and Informatics)</td><td>Aurora, CO</td><td>74</td><td>29</td></tr>
# <tr><td style="text-align:left">30</td><td>University of Massachusetts--Amherst (Division of Biostatistics and Epidemiology)</td><td>Amherst, MA</td><td>79</td><td>30</td></tr>
# <tr><td style="text-align:left">31</td><td>University of South Carolina (Epidemiology and Biostatistics)</td><td>Columbia, SC</td><td>83</td><td>31</td></tr>
# <tr><td style="text-align:left">32</td><td>University at Buffalo--SUNY (Department of Biostatistics)</td><td>Buffalo, NY</td><td>83</td><td>31</td></tr>
# <tr><td style="text-align:left">33</td><td>University of Kansas Medical Center (Department of Biostatistics)</td><td>Kansas City, KS</td><td>89</td><td>33</td></tr>
# <tr><td style="text-align:left">34</td><td>University of Alabama--Birmingham (Department of Biostatistics)</td><td>Birmingham, AL</td><td>89</td><td>33</td></tr>
# <tr><td style="text-align:left">35</td><td>Virginia Commonwealth University (Department of Biostatistics)</td><td>Richmond, VA</td><td>93</td><td>35</td></tr>
# <tr><td style="text-align:left">36</td><td>University of Cincinnati (Division of Epidemiology</td><td>Biostatistics)</td><td>Cincinnati, OH</td><td>93</td></tr>
# <tr><td style="text-align:left">37</td><td>University at Albany--SUNY (Department of Epidemiology</td><td>Biostatistics)</td><td>Rensselaer, NY</td><td>93</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr></table>

# %%
df2
# Out:
#    University
# 1  University of Washington (Department of Biostatistics)
# 2  Johns Hopkins University (Department of Biostatistics)
# 3  Harvard University (Department of Biostatistics)
# 4  University of North Carolina--Chapel Hill (Department of Biostatistics)
# 5  University of Michigan--Ann Arbor (Department of Biostatistics)
# 6  University of California--Berkeley (Group in Biostatistics)
# 7  University of Wisconsin--Madison (School of Medicine and Public Health)
# 8  University of Minnesota--Twin Cities (School of Public Health)
# 9  University of Texas MD Anderson (Department of Biostatistics)
# 10 University of California--Los Angeles (Department of Biostatistics)
# 11 Columbia University (Department of Biostatistics)
# 12 Yale University (Department of Biostatistics)
# 13 University of Pennsylvania (Department of Biostatistics & Epidemiology)
# 14 Emory University (Department of Biostatistics and Bioinformatics)
# 15 Rutgers University--New Brunswick (Department of Statistics and Biostatistics)
# 16 Vanderbilt University (Department of Biostatistics)
# 17 Duke University (Department of Biostatistics and Bioinformatics)
# 18 Brown University (Department of Biostatistics)
# 19 University of Pittsburgh (Department of Biostatistics)
# 20 University of California--Davis (Graduate Group in Biostatistics)
# 21 Boston University (School of Public Health)
# 22 University of Texas Health Science Center--Houston (University of Texas MD Anderson Cancer Center UTHealth)
# 23 University of Rochester (Department of Biostatistics and Computational Biology)
# 24 University of Iowa (Department of Biostatistics)
# 25 University of Florida (Department of Biostatistics)
# 26 Medical College of Wisconsin (Division of Biostatistics)
# 27 University of Illinois--Chicago (Epidemiology and Biostatistics Division)
# 28 Case Western Reserve University (Department of Epidemiology and Biostatistics)
# 29 University of Colorado--Denver (Department of Biostatistics and Informatics)
# 30 University of Massachusetts--Amherst (Division of Biostatistics and Epidemiology)
# 31 University of South Carolina (Epidemiology and Biostatistics)
# 32 University at Buffalo--SUNY (Department of Biostatistics)
# 33 University of Kansas Medical Center (Department of Biostatistics)
# 34 University of Alabama--Birmingham (Department of Biostatistics)
# 35 Virginia Commonwealth University (Department of Biostatistics)
# 36 University of Cincinnati (Division of Epidemiology & Biostatistics)
# 37 University at Albany--SUNY (Department of Epidemiology & Biostatistics)
#    Location         Rank Rank2
# 1  Seattle, WA       3    1
# 2  Baltimore, MD     3    1
# 3  Boston, MA        3    1
# 4  Chapel Hill, NC   8    4
# 5  Ann Arbor, MI    11    5
# 6  Berkeley, CA     12    6
# 7  Madison, WI      24    7
# 8  Minneapolis, MN  24    7
# 9  Houston, TX      27    9
# 10 Los Angeles, CA  27    9
# 11 New York, NY     27    9
# 12 New Haven, CT    31   12
# 13 Philadelphia, PA 31   12
# 14 Atlanta, GA      37   14
# 15 Piscataway, NJ   40   15
# 16 Nashville, TN    44   16
# 17 Durham, NC       44   16
# 18 Providence, RI   44   16
# 19 Pittsburgh, PA   50   19
# 20 Davis, CA        50   19
# 21 Boston, MA       50   19
# 22 Houston, TX      55   22
# 23 Rochester, NY    55   22
# 24 Iowa City, IA    55   22
# 25 Gainesville, FL  55   22
# 26 Milwaukee, WI    61   26
# 27 Chicago, IL      67   27
# 28 Cleveland, OH    69   28
# 29 Aurora, CO       74   29
# 30 Amherst, MA      79   30
# 31 Columbia, SC     83   31
# 32 Buffalo, NY      83   31
# 33 Kansas City, KS  89   33
# 34 Birmingham, AL   89   33
# 35 Richmond, VA     93   35
# 36 Cincinnati, OH   93   35
# 37 Rensselaer, NY   93   35
